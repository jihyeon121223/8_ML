# %%
import urllib.request

# %%
url ='https://www.naver.com/'
urllib.request.urlopen(url).read().decode('utf-8')
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네
# ...

# %%
imgurl='https://img0.yna.co.kr/photo/yna/YH/2022/02/03/PYH2022020309930005100_P4.jpg'
savename = 'testimg01.jpg'
urllib.request.urlretrieve(imgurl,savename)
# Out:
# ('testimg01.jpg', <http.client.HTTPMessage at 0x26e692eefa0>)

# %%
import requests

# %%
requests.get(url)
# Out:
# <Response [200]>

# %%
requests.get(url).text
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네
# ...

# %%
r = requests.get(url)
r.encoding
# Out:
# 'UTF-8'

# %%
requests.get('https://api.github.com/events').text
# Out:
# '[{"id":"20670175893","type":"PushEvent","actor":{"id":45184110,"login":"jayjayoikeh","display_login":"jayjayoikeh","gravatar_id":"","url":"https://api.github.com/users/jayjayoikeh","avatar_url":"https://avatars.githubusercontent.com/u/45184110?"},"repo":{"id":465611548,"name":"jayjayoikeh/Major-Group-Project-2021","url":"https://api.github.com/repos/jayjayoikeh/Major-Group-Project-2021"},"payload":{"push_id":9311190678,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"0aa468185b459fa616c3f5f0ae6d0754af1ec3c7","before":"2a601e8c45cd1526447ca92e5bff7d66a1cca560","commits":[{"sha":"0aa468185b459fa616c3f5f0ae6d0754af1ec3c7","author":{"email":"45184110+jayjayoikeh@users.noreply.github.com","name":"jayjayoikeh"},"message":"Add files via upload","distinct":true,"url":"https://api.github.com/repos/jayjayoikeh/Major-Group-Project-2021/commits/0aa468185b459fa616c3f5f0ae6d0754af1ec3c7"}]},"public":true,"created_at":"2022-03-10T00:42:36Z"},{"id":"20670175859","type":"PushEvent","actor"
# ...

# %%
requests.get('https://api.github.com/events').json()
# Out:
# [{'id': '20670177811',
#   'type': 'CreateEvent',
#   'actor': {'id': 88677,
#    'login': 'pocketninja',
#    'display_login': 'pocketninja',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pocketninja',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/88677?'},
#   'repo': {'id': 468119106,
#    'name': 'pocketninja/enjine-blue-and-green',
#    'url': 'https://api.github.com/repos/pocketninja/enjine-blue-and-green'},
#   'payload': {'ref': 'playable-pages',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'A simple x/o game with my toy engine, Enjine',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-03-10T00:42:48Z'},
#  {'id': '20670177799',
#   'type': 'CreateEvent',
#   'actor': {'id': 98179896,
#    'login': 'spicyshrekk',
#    'display_login': 'spicyshrekk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/spicyshrekk',
# ...

# %% [raw]
# https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%EC%B4%88%EC%BD%94%EB%A6%BF

# %%
from urllib.request import urlopen
from urllib.parse import urlencode

# %%
api = 'https://search.naver.com/search.naver'
values = {
    'where':'nexearch',
    'sm':'top_hty',
    'fbm':1,
    'ie':'utf8',
    'query':'벗꽃'
}

# %%
params = urlencode(values)
params
# Out:
# 'where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%EB%B2%97%EA%BD%83'

# %%
url = api+'?'+params
url
# Out:
# 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%EB%B2%97%EA%BD%83'

# %%
urlopen(url).read().decode('utf-8')
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="벗꽃 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'벗꽃\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'벗꽃\'의 네이버 통합검색 결과입니다."> <title>벗꽃 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_220303.css"> <link rel="stylesheet" type="text/css" href="
# ...

# %%
requests.get(api,params=values).text
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="벗꽃 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'벗꽃\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'벗꽃\'의 네이버 통합검색 결과입니다."> <title>벗꽃 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_220303.css"> <link rel="stylesheet" type="text/css" href="
# ...

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
print(requests.post("https://httpbin.org/post", data=payload).text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.26.0",
#     "X-Amzn-Trace-Id": "Root=1-62295c23-63de8e7d0ae05192438368f7"
#   },
#   "json": null,
#   "origin": "210.119.14.56",
#   "url": "https://httpbin.org/post"
# }

# %%
data = urlencode(payload)
r = urllib.request.Request("https://httpbin.org/post",payload)
urlopen(r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12600/3651338557.py in <module>
#       1 data = urlencode(payload)
#       2 r = urllib.request.Request("https://httpbin.org/post",payload)
# ----> 3 urlopen(r)
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     515
#     516         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517         response = self._open(req, data)
#     518
#     519         # post-process response
#
# ~\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     532
# ...
